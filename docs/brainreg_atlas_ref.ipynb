# %% [markdown]
# # Atlas brain regions reference

# %% [markdown]
# ## For **allen_mouse_25um** atlas

# %%
from bg_atlasapi import BrainGlobeAtlas
import pandas as pd

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    df = BrainGlobeAtlas("allen_mouse_25um").lookup_df[["id", "name"]]
    print(df)
# Out:
#             id                                               name
# 0          997                                               root
# 1            8                      Basic cell groups and regions
# 2          567                                           Cerebrum
# 3          688                                    Cerebral cortex
# 4          695                                     Cortical plate
# 5          315                                          Isocortex
# 6          184                      Frontal pole, cerebral cortex
# 7           68                              Frontal pole, layer 1
# 8          667                            Frontal pole, layer 2/3
# 9    526157192                              Frontal pole, layer 5
# 10   526157196                             Frontal pole, layer 6a
# 11   526322264                             Frontal pole, layer 6b
# 12         500                                  Somatomotor areas
# ...

# %% [markdown]
# ## For **allen_mouse_10um** atlas

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    df = BrainGlobeAtlas("allen_mouse_10um").lookup_df[["id", "name"]]
    print(df)
# Out:
#             id                                               name
# 0          997                                               root
# 1            8                      Basic cell groups and regions
# 2          567                                           Cerebrum
# 3          688                                    Cerebral cortex
# 4          695                                     Cortical plate
# 5          315                                          Isocortex
# 6          184                      Frontal pole, cerebral cortex
# 7           68                              Frontal pole, layer 1
# 8          667                            Frontal pole, layer 2/3
# 9    526157192                              Frontal pole, layer 5
# 10   526157196                             Frontal pole, layer 6a
# 11   526322264                             Frontal pole, layer 6b
# 12         500                                  Somatomotor areas
# ...
